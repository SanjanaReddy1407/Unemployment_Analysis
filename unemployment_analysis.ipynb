# %%
import pandas as pd

# %%
data = pd.read_csv("unemploy.csv")

# %%
data.describe()
# Out:
#        Estimated Unemployment Rate (%)  Estimated Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated Labour Participation Rate (%)
# count                               740.000000
# mean                                 42.630122
# std                                   8.111094
# min                                  13.330000
# 25%                                  38.062500
# 50%                                  41.160000
# 75%                                  45.505000
# max                                  72.570000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
data.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
data.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
data_new = data.dropna(how='all')

# %%
data_new.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
data_clean = data_new.drop_duplicates(subset=['Region'])

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 0 to 415
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    28 non-null     object
#  1    Date                                     28 non-null     object
#  2    Frequency                                28 non-null     object
#  3    Estimated Unemployment Rate (%)          28 non-null     float64
#  4    Estimated Employed                       28 non-null     float64
#  5    Estimated Labour Participation Rate (%)  28 non-null     float64
#  6   Area                                      28 non-null     object
# dtypes: float64(3), object(4)
# memory usage: 1.8+ KB

# %%
data_clean.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
data_clean.to_csv("finaldata.csv", index=False)
print("download successful")
# Out:
# download successful

# %%
import matplotlib.pyplot as mp

# %%
import seaborn as s

# %%
plt.figure(figsize=(14, 6))
state_unemp = data_clean.groupby('Region')[' Estimated Unemployment Rate (%)'].mean().sort_values(ascending=False).reset_index()
sns.barplot(data=state_unemp,  y='Region', palette='coolwarm')
plt.title('Average Unemployment Rate by Region / State', fontsize=14, fontweight='bold')
plt.xlabel('Average Unemployment Rate (%)')
plt.ylabel('States / Regions')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14936\4019928882.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=state_unemp,  y='Region', palette='coolwarm')

# %%
plt.figure(figsize=(12, 8))
# Grouping by Region and sorting by the unemployment rate
state_unemp = data_clean.groupby('Region')[' Estimated Unemployment Rate (%) '].mean().sort_values(ascending=False).reset_index()

sns.barplot(data=state_unemp, x='Estimated Unemployment Rate (%)', y='Region', palette='viridis')
plt.title('Average Unemployment Rate by Region/State', fontsize=14, fontweight='bold')
plt.xlabel('Average Unemployment Rate (%)', fontsize=12)
plt.ylabel('Region / State', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 3
#       1 plt.figure(figsize=(12, 8))
#       2 # Grouping by Region and sorting by the unemployment rate
# ----> 3 state_unemp = data_clean.groupby('Region')[' Estimated Unemployment Rate (%) '].mean().sort_values(ascending=False).reset_index()
#       5 sns.barplot(data=state_unemp, x='Estimated Unemployment Rate (%)', y='Region', palette='viridis')
#       6 plt.title('Average Unemployment Rate by Region/State', fontsize=14, fontweight='bold')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
# ...
